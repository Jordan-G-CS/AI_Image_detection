# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2" # suppress info and warning messages
import tensorflow.keras as keras
import math
import time
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# import sys; print(sys.executable)

# %% [markdown]
# Code below is for importing dataset(s) from Kaggle

# %%
# !pip install kagglehub

# %%
import kagglehub
# from kagglehub import KaggleDatasetAdapter

# testing to make sure kagglehub actually works
# df = kagglehub.dataset_load(
#     KaggleDatasetAdapter.PANDAS,
#     "unsdsn/world-happiness/versions/1",
#     "2016.csv",
# )
# yh nvm, looked on stackoverflow, may have to just download it all

# I mean this works, it just downloads EVERYTHING!

path = kagglehub.dataset_download("tristanzhang32/ai-generated-images-vs-real-images")

print("Path to dataset files:", path)
# Out:
# ...
#   1%|          | 471M/48.4G [01:05<1:53:24, 7.57MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 12
#       8 #     "2016.csv",
#       9 # )
#      10 # yh nvm, looked on stackoverflow, may have to just download it all
#      11
# ---> 12 path = kagglehub.dataset_download("tristanzhang32/ai-generated-images-vs-real-images")
#      13
#      14 print("Path to dataset files:", path)
#      15
#
# File /opt/anaconda3/envs/tf_env/lib/python3.11/site-packages/kagglehub/datasets.py:52, in dataset_download(handle, path, force_download, output_dir)
#      50 h = parse_dataset_handle(handle)
#      51 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 52 resolved_path, _ = registry.dataset_resolver(
#      53     h,
#      54     path,
#      55     force_download=force_download,
#      56     output_dir=output_dir,
# ...
